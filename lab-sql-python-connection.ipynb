# %%
import mysql.connector
from sqlalchemy import create_engine
from getpass import getpass
import pandas as pd
from sqlalchemy import text

# %%
#Challenge 1.

# %%
my_password = getpass()

#connection to sql from python
cnx = mysql.connector.connect(user = "root", 
                              password = my_password,
                               host = "localhost",
                                database = "sakila" )
cursor = cnx.cursor()

# %%
#Challenge 2.

# %%
def rentals_month(engine, month, year):

    query = text("""
    SELECT *
    FROM rental
    WHERE EXTRACT(MONTH FROM rental_date) = :month
      AND EXTRACT(YEAR FROM rental_date) = :year
    """)
    
    with engine.connect() as connection:
        df = pd.read_sql(query, connection, params={"month": month, "year": year})
    
    return df

user = "root"
pw = getpass()
db = "sakila"

engine = create_engine(f"mysql+pymysql://{user}:{pw}@localhost/{db}")

month = int(input("Input the month number: "))
year = int(input("Input the year: "))
df_rentals = rentals_month(engine, month, year)

df_rentals
# Out:
#       rental_id         rental_date  inventory_id  customer_id  \
# 0             1 2005-05-24 22:53:30           367          130
# 1             2 2005-05-24 22:54:33          1525          459
# 2             3 2005-05-24 23:03:39          1711          408
# 3             4 2005-05-24 23:04:41          2452          333
# 4             5 2005-05-24 23:05:21          2079          222
# ...         ...                 ...           ...          ...
# 1151       1153 2005-05-31 21:36:44          2725          506
# 1152       1154 2005-05-31 21:42:09          2732           59
# 1153       1155 2005-05-31 22:17:11          2048          251
# 1154       1156 2005-05-31 22:37:34           460          106
# 1155       1157 2005-05-31 22:47:45          1449           61
#
#              return_date  staff_id         last_update
# 0    2005-05-26 22:04:30         1 2006-02-15 21:30:53
# 1    2005-05-28 19:40:33         1 2006-02-15 21:30:53
# ...

# %%
#Challenge 3.

# %%
def rentals_count_month(engine, month, year):

    query = text("""
    SELECT *
    FROM rental
    WHERE EXTRACT(MONTH FROM rental_date) = :month
      AND EXTRACT(YEAR FROM rental_date) = :year
    GROUP BY rental_id
    """)
    
    with engine.connect() as connection:
        df = pd.read_sql(query, connection, params={"month": month, "year": year})
    
    return df

user = "root"
pw = getpass()
db = "sakila"

engine = create_engine(f"mysql+pymysql://{user}:{pw}@localhost/{db}")

month = int(input("Input the month number: "))
year = int(input("Input the year: "))
df_rentals_count = rentals_month(engine, month, year)

df_rentals_count["rental_m_y"] = f"rental_{month}_{year}"

df_rentals_count
# Out:
#       rental_id         rental_date  inventory_id  customer_id  \
# 0             1 2005-05-24 22:53:30           367          130
# 1             2 2005-05-24 22:54:33          1525          459
# 2             3 2005-05-24 23:03:39          1711          408
# 3             4 2005-05-24 23:04:41          2452          333
# 4             5 2005-05-24 23:05:21          2079          222
# ...         ...                 ...           ...          ...
# 1151       1153 2005-05-31 21:36:44          2725          506
# 1152       1154 2005-05-31 21:42:09          2732           59
# 1153       1155 2005-05-31 22:17:11          2048          251
# 1154       1156 2005-05-31 22:37:34           460          106
# 1155       1157 2005-05-31 22:47:45          1449           61
#
#              return_date  staff_id         last_update     rental_m_y
# 0    2005-05-26 22:04:30         1 2006-02-15 21:30:53  rental_5_2005
# ...

# %%
def rentals_count_month(engine, month, year):

    query = text("""
    SELECT *
    FROM rental
    WHERE EXTRACT(MONTH FROM rental_date) = :month
      AND EXTRACT(YEAR FROM rental_date) = :year
    GROUP BY rental_id
    """)
    
    with engine.connect() as connection:
        df = pd.read_sql(query, connection, params={"month": month, "year": year})
    
    return df

user = "root"
pw = getpass()
db = "sakila"

engine = create_engine(f"mysql+pymysql://{user}:{pw}@localhost/{db}")

month = int(input("Input the month number: "))
year = int(input("Input the year: "))
df_rentals_count2 = rentals_month(engine, month, year)

df_rentals_count2["rental_m_y"] = f"rental_{month}_{year}"

df1 = df_rentals_count
df2 = df_rentals_count2

df_combined = pd.merge(df1, df2, on="rental_id", how="outer")
